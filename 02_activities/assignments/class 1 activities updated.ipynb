# %%
#import these libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy

# %%
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0,100,50) #first value is our min, 2nd is our max, 3rd is our
#Creating a scattered diagram
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y)

# %%
fig, ax = plt.subplots (figsize=(5,3)) #This produces the size of the diagram
ax.plot(x,y) #to make it bar

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.hist(y) #This produces the histogram.
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y)

ax.set_title('Total growth over time') #The title of the graph that will be produced
ax.set_ylabel('Total Growth') #The label on the y axis
ax.set_xlabel('Years since start') #The label on the x axis
# Out:
# Text(0.5, 0, 'Years since start')

# %%
font1 ={'family':'san-serif','color':'blue','size':20}
font2 = {'family':'monospace', 'color': 'green', 'size' :14}

fig, ax = plt.subplots(figsize = (5,3))
ax.plot(x,y)
ax.set_title('Total growth over time', fontdict = font1, loc = 'left')
ax.set_ylabel('Total growth', fontdict = font2)
ax.set_xlabel('Years since start', fontdict = font2)
# Out:
# Text(0.5, 0, 'Years since start')
# findfont: Font family 'san-serif' not found.
# findfont: Font family 'san-serif' not found.
# findfont: Font family 'san-serif' not found.
# findfont: Font family 'san-serif' not found.
# findfont: Font family 'san-serif' not found.
# findfont: Font family 'san-serif' not found.

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y,
           marker = '*', #The marker in the graph should be represented by a star
           color = 'indigo', #the color of the lines and stars in the graph
           linestyle = '--', #The lines should be dotted
           linewidth = 2)

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y,
           marker = '*',
           color = 'indigo',
           linestyle = '--',
           linewidth = 2,
           markeredgecolor ='#FA9359',
           markerfacecolor = '000000')

# %%
# libraries
import numpy as np
from numpy import linspace
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde

# dataframe
df = pd.DataFrame({
'var1': np.random.normal(size=1000),
'var2': np.random.normal(loc=2, size=1000) * -1
})

# Fig size
plt.rcParams["figure.figsize"]=12,8

# plot density chart for var1
sns.kdeplot(data=df, x="var1",  fill=True, alpha=1)

# plot density chart for var2
kde = gaussian_kde(df.var2)
x_range = linspace(min(df.var2), max(df.var2), len(df.var2))

# multiply by -1 to reverse axis (mirror plot)
sns.lineplot(x=x_range*-1, y=kde(x_range) * -1, color='orange') 
plt.fill_between(x_range*-1, kde(x_range) * -1, color='orange')

# add axis names        
plt.xlabel("value of x")
plt.axhline(y=0, linestyle='-',linewidth=1, color='black')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0, 100, 50)
y2 = np.random.randint(0, 100, 50)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y1)
ax.plot(x, y2)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y1, label = 'person 1')
ax.plot(x, y2, label = 'person 2')

# %%
#Import all libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
from PIL import Image
import requests
from io import BytesIO

# %%
np.random.seed(613)
x = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])
y2 = np.array([170, 100, 90, 120, 50])

# %%
y2_sd = np.std(y2)

fig, ax = plt.subplots(figsize=(7,3))
ax.plot(x,y2, color = "red")

ax.errorbar(x, y2,
            yerr = y2_sd,
            fmt = "none",
            ecolor= "indigo",
            elinewidth= 4,
            capsize= 6,
            capthick= 4)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
from PIL import Image #to open images
import requests # to get images from URLS
from io import BytesIO # to stores images

# %%
response = requests.get ('https://upload.wikimedia.org/wikipedia/en/c/cb/Monkey_D_Luffy.png')
image_file = BytesIO(response.content)
image = Image.open (image_file)

# %%
fig, ax = plt.subplots(figsize=(7,3))
ax.plot(x, y2, color = "red")

ax_image = fig.add_axes([0.1, 0.11, 0.15, 0.35])

ax_image.imshow(image)
ax_image.axis
# Out:
# <bound method _AxesBase.axis of <Axes: >>
